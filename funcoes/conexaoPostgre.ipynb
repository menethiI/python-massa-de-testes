# %%
import psycopg2
from sqlalchemy import create_engine, text

# %%
#conexão com o banco
conn = create_engine(f'postgresql+psycopg2://postgres:ContSQL2017%40@192.168.5.27/erp')

# %%
#fazendo uma query no banco
query = '''
    select codigo
    from tributacao where contmatic_id = 32725;
'''
result = conn.connect().execute(text(query))

# %%
list(map(lambda e: e[0], list(result)))
# Out:
# ['TESTE DIFAL',
#  'fcp',
#  'teste simples nacion',
#  '12',
#  'marcio00',
#  'qqqqqqq',
#  '71042100',
#  'difal rpa',
#  'marcio30',
#  'marcio40',
#  'marcio41',
#  'marcio50',
#  '21323',
#  'ASASA',
#  '132332',
#  '33012914',
#  '2312',
#  'reducao RPA',
#  'marcio60',
#  'MARCIO10',
#  'MARCIO20',
#  'MARCIO90',
#  '34234234',
#  '122334455',
#  'ADD TRIB2',
#  'ADD TRIB22',
#  'ADD TRIB15',
#  'AGORAVAI',
#  'ADDTRIBBBB',
#  'fastest',
#  'testttt',
#  'ttttest',
#  'TESTEADD',
#  'tteesstt',
#  'tteessttee',
#  'ssssss',
#  'ahhhhhhhhhh',
#  'asdfg',
#  'qwerty',
#  'dsadasda',
#  'gfgfgf',
#  '5345345',
#  'TRRRIB',
#  'WWWW',
#  'dsadsa',
#  '5544',
#  '11222',
#  'qasw',
#  'SWSW',
#  'fdsafds',
#  'qwert',
#  '900',
#  'CSOSN102',
#  '000000',
#  'teste_ICMS-ST',
#  'lalala',
#  'AUTO900',
#  'enqu',
#  'gagaga',
#  'jajaja',
#  'cxzczxc',
#  'coden',
#  'ururur',
#  'eenn',
#  'eeennn',
#  'LP102',
#  '777777777777',
#  'ccoo',
#  '4040440044004',
#  '444',
#  '112233',
#  'cod enq',
#  'foi',
#  'xasdasdasd',
#  'cxzczxczxc',
#  'cxzczxcz',
#  '3333',
#  '1122',
#  'LP120-E',
#  'TRIBB FULL',
#  '111111',
#  'foiiii',
#  'reso',
#  'hahahahha',
#  'QQQQ',
#  'CSOSN900',
#  '1111',
#  'zxzx',
#  'TESTTTTT',
#  '1234',
#  'TTRRIIBB',
#  'negresco',
#  'QAZQAZ',
#  'wsxwsx',
#  'dddddd',
#  'ewwewe',
#  'zazaza',
#  'asuidghuhasd',
#  'mamama',
#  'gdgdgdg',
#  'zsezse',
#  '3232',
#  '5454',
#  'gygygy',
#  '55555',
#  '09876',
#  '8899',
#  'hgfd',
#  'acacac',
#  'qweeqwdasads',
#  '7878',
#  '6543',
#  '333355',
#  '604',
#  '77777',
#  '434343',
#  '765432',
#  'gegegeg',
#  'dadasd',
#  'TESTANDOOOO ',
#  'tribzinha',
#  'fafaf',
#  'zszs',
#  'dwdwdw',
#  'drdrdr',
#  '4141',
#  'kjhkjh',
#  'gtgtgt',
#  '7373',
#  'bgbgbg',
#  'triiiiiib',
#  'adddd triib',
#  'hdhdhd',
#  '776',
#  '314',
#  '778877',
#  'trib ne',
#  '656565',
#  '753',
#  '117',
#  '966',
#  'teste jessica',
#  '048',
#  '159',
#  '998877',
#  '778899',
#  '5674567',
#  '456456',
#  '4352345',
#  '523452',
#  '587568',
#  '6457834568',
#  '5678568907',
#  '538736675',
#  'Teste difal icms st',
#  '9867585',
#  '65895678',
#  '500',
#  '345345',
#  '43534',
#  '423423',
#  '4567456',
#  '34534534',
#  '34534534444',
#  '34534534444567',
#  '56456456',
#  '9678',
#  '786785',
#  '9789678',
#  '5467956',
#  '345683',
#  '96789678',
#  '654564',
#  '3487568',
#  '345312456',
#  '4564',
#  '567567',
#  '456245',
#  '7686654756',
#  '104',
#  '33331',
#  '103',
#  '62063001',
#  'LP difal',
#  '123',
#  'Difal icms st',
#  '1134',
#  '1603',
#  'DIFALTODAS',
#  'testeteste',
#  'Testes Lucas',
#  '123456789',
#  '0933',
#  'DEV DIFAL',
#  'TESTEDIFAL',
#  '400',
#  '500DIFAL',
#  '85395000',
#  'testebru',
#  '23123123213123',
#  '999999999987',
#  '62063000',
#  '99999',
#  '2422331',
#  '1322332321312',
#  '4673246',
#  '8937324',
#  '98828744',
#  '76438',
#  '8765476',
#  '08472803',
#  '2193981729837123',
#  '3123123',
#  'INATIVO',
#  '12354',
#  '069',
#  'Geral',
#  '1222',
#  'testeee',
#  'LP reducao bases',
#  '23342',
#  '55555555555',
#  '12233344445555666666',
#  '0011AABB09078743',
#  '222',
#  '233',
#  '1234221666558789',
#  '122',
#  '2226',
#  '555',
#  '1223',
#  '22234',
#  '2000',
#  'cst60',
#  'cst_60',
#  'testeRepasse']
